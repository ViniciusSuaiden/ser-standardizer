# %%
import ser_standardizer as ser

# %%
df_all = ser.load_datasets(["crema_d", "ravdess", "iemocap"])

# %%
df_all
# Out:
#        dataset                                          file_path  \
# 0      CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...
# 1      CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...
# 2      CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...
# 3      CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...
# 4      CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...
# ...        ...                                                ...
# 18916  IEMOCAP  C:\Users\Vinicius Suaiden\Downloads\Datasets\I...
# 18917  IEMOCAP  C:\Users\Vinicius Suaiden\Downloads\Datasets\I...
# 18918  IEMOCAP  C:\Users\Vinicius Suaiden\Downloads\Datasets\I...
# 18919  IEMOCAP  C:\Users\Vinicius Suaiden\Downloads\Datasets\I...
# 18920  IEMOCAP  C:\Users\Vinicius Suaiden\Downloads\Datasets\I...
#
#            speaker_id gender  emotion  \
# 0          crema_1001   Male    Anger
# 1          crema_1001   Male  Disgust
# 2          crema_1001   Male     Fear
# ...

# %%
df_filtered = ser.filters(
    df_all,
    datasets='crema-d',
    emotions=['anger', 'happy'], 
    genders=['female'],
)
# Out:
# Filtro aplicado. Restaram 779 amostras.

# %%
df_filtered
# Out:
#       dataset                                          file_path  speaker_id  \
# 82    CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1002
# 85    CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1002
# 89    CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1002
# 90    CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1002
# 104   CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1002
# ...       ...                                                ...         ...
# 7403  CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1091
# 7418  CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1091
# 7424  CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1091
# 7430  CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1091
# 7436  CREMA-D  C:\Users\Vinicius Suaiden\Downloads\Datasets\D...  crema_1091
#
# ...

# %%
features = ser.extract_features(df_filtered, feature_set='eGeMAPS', use_vad=False, sr=16000)
# Out:
# Inicializando openSMILE (eGeMAPS)...
# Extraindo características:   0%|          | 0/779 [00:00<?, ?it/s]
# Consolidando matriz de features...

# %%
features
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 82                            46.862366
# 85                            43.874290
# 89                            44.639236
# 90                            42.510792
# 104                           42.937481
# ...                                 ...
# 7403                          29.964607
# 7418                          39.250851
# 7424                          36.595932
# 7430                          40.629562
# 7436                          29.633892
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 82                                  0.031873
# 85                                  0.061580
# 89                                  0.094351
# 90                                  0.121605
# 104                                 0.073497
# ...                                      ...
# 7403                                0.180377
# 7418                                0.070699
# 7424                                0.179450
# ...

# %%
import opensmile

for feature_set in opensmile.FeatureSet:
    print(feature_set.name)
# Out:
# ComParE_2016
# GeMAPS
# GeMAPSv01b
# eGeMAPS
# eGeMAPSv01b
# eGeMAPSv02
# emobase
# IS09
# IS10
# IS11
# IS12
# IS13

# %% [markdown]
# (e)GeMAPS: minimalista, dados selecionados teoricamente (menos de 100)
# IS e ComParE: Força bruta (milhares)
# emobase: intermediário clássico, usado como baseline

# %% [markdown]
# smile = opensmile.Smile(
#     feature_set = opensmile.FeatureSet.eGeMAPSv02,
#     feature_level = opensmile.FeatureLevel.LowLevelDescriptors,
# )
